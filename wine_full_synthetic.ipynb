# %% [markdown]
# .ipynb folder for testing model collapse on two general machine learning models: random forest & linear regression.
#
# To start, there will be several tests of the machine learning models to try and maximize accuracy before the

# %% [markdown]
# Setup: import libraries, create dataset, etc.

# %%
                 

# using alexhusted's random forest project as reference for implementing random forest
import random
from collections import defaultdict
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import SkLearn
from sklearn import tree, preprocessing
import sklearn.ensemble as ske
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

# %%
# dataset with pandas
url = "https://archive.ics.uci.edu/static/public/186/data.csv"
wine_data = pd.read_csv(url, sep=',')

# %%
# change red -> 0, white -> 1 so they're useable in the model
color = {'red': 0,'white': 1} 
wine_data.color = [color[item] for item in wine_data.color] 
#print(wine_data.describe())
print()
print(wine_data.dtypes)
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                     int64
# dtype: object

# %% [markdown]
# Correlation Matrix: I'm using a correlation matrix to examine which categories in the dataset have too strong of a correlation with other categories so that they can be removed to prevent overfitting.

# %%
corr_matrix = wine_data.corr()
#print(corr_matrix)
# Plot the new correlation matrix based upon the created dataframe 'corr_df'
plt.figure(figsize=(13,13))
sns.heatmap(corr_matrix, cmap='YlGnBu', vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
# Remove the "total_sulfur_dioxide" category because of high correlations
wine_data_init = wine_data
wine_data = wine_data.drop('total_sulfur_dioxide', axis=1)

# drop a row to keep totals even

# %%
# Remove red wine entries (and 'color' category) because skew of data
#wine_data = wine_data[wine_data.color != 0]
#wine_data = wine_data.drop('color', axis=1)

# %% [markdown]
# Random Forest Model

# %%
# create datasets with and without 'quality'
Xa1 = wine_data.drop(['quality'], axis=1)
ya1 = wine_data['quality']

# %%
# train/test split on the data
# doing 50% split because of equal data in repeated generations
Xa1_train, Xa1_test, ya1_train, ya1_test = train_test_split(Xa1, ya1, test_size=0.5, random_state=123)

# normalize the sizes of the dataframes
Xa1_test = Xa1_test.tail(-1)
ya1_test = ya1_test.tail(-1)

#confirm the data
print(Xa1_test)
print(ya1_test)
print(Xa1_train)
print(ya1_train)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 2767            7.2              0.20         0.38            1.00      0.037
# 5069            6.7              0.24         0.30            3.85      0.042
# 5780            6.6              0.25         0.32            5.60      0.039
# 547            10.6              0.31         0.49            2.50      0.067
# 1769            7.1              0.30         0.46            1.50      0.066
# ...             ...               ...          ...             ...        ...
# 2332            6.6              0.25         0.30           14.40      0.052
# 1920            6.6              0.24         0.35            7.70      0.031
# 3125           14.2              0.27         0.49            1.10      0.037
# 44              6.8              0.67         0.02            1.80      0.050
# 789             8.6              0.63         0.17            2.90      0.099
#
#       free_sulfur_dioxide  density    pH  sulphates  alcohol  color
# 2767                 21.0  0.99180  3.21       0.37     11.0      1
# 5069                105.0  0.99189  3.04       0.59     11.3      1
# 5780                 15.0  0.99163  2.96       0.52     11.1      1
# 547                   6.0  0.99870  3.26       0.86     10.7      0
# 1769                 29.0  0.99060  3.12       0.54     12.7      1
# ...                   ...      ...   ...        ...      ...    ...
# 2332                 40.0  0.99800  3.02       0.50      9.1      1
# 1920                 36.0  0.99380  3.19       0.37     10.5      1
# 3125                 33.0  0.99200  3.15       0.54     11.1      1
# 44                    5.0  0.99620  3.48       0.52      9.5      0
# 789                  21.0  0.99800  3.09       0.52      9.3      0
#
# [3248 rows x 11 columns]
# 2767    5
# 5069    8
# 5780    6
# 547     6
# 1769    6
#        ..
# 2332    6
# 1920    5
# 3125    6
# 44      5
# 789     5
# Name: quality, Length: 3248, dtype: int64
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 2653            7.0             0.310         0.52            1.70      0.029
# 1376            8.2             0.885         0.20            1.40      0.086
# 2693            7.4             0.240         0.31            8.40      0.045
# 6269            6.6             0.285         0.49           11.40      0.035
# 3319            7.6             0.200         0.39            2.60      0.044
# ...             ...               ...          ...             ...        ...
# 5218            6.8             0.450         0.28           26.05      0.031
# 4060            8.2             0.260         0.33            2.60      0.053
# 1346            6.1             0.590         0.01            2.10      0.056
# 3454            8.0             0.220         0.28           14.00      0.053
# 3582            7.6             0.200         0.30           14.20      0.056
#
#       free_sulfur_dioxide  density    pH  sulphates  alcohol  color
# 2653                  5.0  0.99180  3.07       0.43     10.4      1
# 1376                  7.0  0.99460  3.11       0.46     10.0      0
# 2693                 52.0  0.99630  3.09       0.32      8.8      1
# 6269                 57.0  0.99732  3.08       0.54      8.9      1
# 3319                 30.0  0.99410  3.46       0.44     10.8      1
# ...                   ...      ...   ...        ...      ...    ...
# 5218                 27.0  1.00295  3.06       0.42     10.6      1
# 4060                 11.0  0.99402  2.89       0.49      9.5      1
# 1346                  5.0  0.99472  3.52       0.56     11.4      0
# 3454                 83.0  0.99810  3.14       0.45      9.8      1
# 3582                 53.0  0.99900  3.14       0.46      8.9      1
#
# [3248 rows x 11 columns]
# 2653    5
# 1376    5
# 2693    5
# 6269    6
# 3319    7
#        ..
# 5218    6
# 4060    5
# 1346    5
# 3454    6
# 3582    8
# Name: quality, Length: 3248, dtype: int64

# %%
# initialize rf model (sklearn)
rf_model = RandomForestClassifier(n_estimators=100)
# fit the model on the train data
rf_model.fit(Xa1_train, ya1_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Examining Results

# %%
# Print the model score based upon the random forest classifier
acc1 = rf_model.score(Xa1_test,ya1_test)
print(acc1)
# Out:
# 0.6394704433497537

# %%
def generate_synthetic_features(rf_model, num_samples, X_train):
    """
    Follow (Watson et. al. 2023) for synthetic feature generation
    draw synthetic rows from model
    - continuous features bootstrapped from leaf members and jittered
    - categorical features sampled from leaf's empirical distribution
    """

    jitter = 0.05

    # use random number generator for reproducibility
    rng = np.random.default_rng() 

    features = X_train.columns
    nodes = [t.tree_ for t in rf_model.estimators_]

    # pre-index real rows that fall in each (tree, leaf) pair
    membership = defaultdict(list) 
    for i, estimator in enumerate(rf_model.estimators_):
        leaf_ids = estimator.apply(X_train.values)
        for j, leaf_id in enumerate(leaf_ids):
            membership[(i, leaf_id)].append(j)

    synthetic = []

    while len(synthetic) < num_samples:
        # choose a random tree, leaf
        tree_idx = rng.integers(len(nodes))
        tree = nodes[tree_idx]
        leaves = tree.children_left == tree.children_right
        leaf = rng.choice(np.where(leaves)[0], p=tree.n_node_samples[leaves] / tree.n_node_samples[0])

        # get the rows in the leaf
        rows = membership[(tree_idx, leaf)]
        if not rows:
            continue
        
        base = X_train.iloc[rng.choice(rows)].copy()

        # jitter continuous features
        for col in base.index:
            if np.issubdtype(X_train[col].dtype, np.number):
                sigma = jitter * X_train[col].std(ddof=0)
                base[col] += rng.normal(0, sigma)
        
        synthetic.append(base)

    # convert to DataFrame
    return pd.DataFrame(synthetic, columns=features)

"""
def generate_synthetic_features(rf_model, num_samples, X_train):
    synthetic_samples = []
    feature_names = X_train.columns

    # Precompute min and max for each feature
    feature_min = X_train.min()
    feature_max = X_train.max()

    # Iterate until we have generated the required number of synthetic samples
    while len(synthetic_samples) < num_samples:
        # Choose a random tree from the Random Forest
        random_tree = random.choice(rf_model.estimators_)
        tree = random_tree.tree_
        
        # Create an empty synthetic sample with NaN values
        synthetic_sample = np.full(len(feature_names), np.nan)
        
        # Start from the root node and traverse until a leaf is reached
        node_id = 0  # Start at the root node
        
        while tree.children_left[node_id] != tree.children_right[node_id]:
            left_child = tree.children_left[node_id]
            right_child = tree.children_right[node_id]
            feature = tree.feature[node_id]
            threshold = tree.threshold[node_id]

            # Get number of samples going left and right
            n_node_samples = tree.n_node_samples[node_id]
            n_left = tree.n_node_samples[left_child]
            n_right = tree.n_node_samples[right_child]

            # Compute probabilities
            p_left = n_left / n_node_samples
            p_right = n_right / n_node_samples

            # Decide to go left or right based on probabilities
            if random.random() < p_left:
                # Go to the left child (value <= threshold)
                min_val = feature_min[feature_names[feature]]
                max_val = threshold
                node_id = left_child
            else:
                # Go to the right child (value > threshold)
                min_val = threshold
                max_val = feature_max[feature_names[feature]]
                node_id = right_child

            # Sample a value for the feature (if not already set)
            if np.isnan(synthetic_sample[feature]):
                synthetic_sample[feature] = random.uniform(min_val, max_val)
            
        # For features not set, assign random values within min and max
        for i in range(len(feature_names)):
            if np.isnan(synthetic_sample[i]):
                synthetic_sample[i] = random.uniform(feature_min[feature_names[i]], feature_max[feature_names[i]])

        # Append the generated sample to the list
        synthetic_samples.append(synthetic_sample)
    
    # Convert the list of synthetic samples to a DataFrame
    X_synthetic = pd.DataFrame(synthetic_samples, columns=feature_names)

    return X_synthetic
    """

# %%
accuracies = []
accuracies.append(acc1)
iterations = []
iterations.append(0)

X_synthetic = generate_synthetic_features(rf_model, 3248, Xa1_train)

for i in range(1, 21):
    # Step 1: Generate new synthetic features based on current training set
    X_synthetic = generate_synthetic_features(rf_model, 3248, X_synthetic)
    
    # Step 2: Use the current model to predict labels for the synthetic data
    y_synthetic = rf_model.predict(X_synthetic)
    
    # Step 4: Train a new Random Forest model on the synthetic dataset
    rf_model = RandomForestClassifier(n_estimators=100)
    rf_model.fit(X_synthetic, y_synthetic)
    
    # Step 5: Evaluate the new model on the original fixed test set
    y_test_pred = rf_model.predict(Xa1_test)
    accuracy = accuracy_score(ya1_test, y_test_pred)
    
    # Print the iteration and accuracy
    print(f"Iteration {i}: Accuracy = {accuracy:.4f}")
    cm = confusion_matrix(y_true=ya1_test, y_pred=y_test_pred)
    print(f"Confusion Matrix:\n{cm}\n")
    
    # Append the accuracy and iteration number to the lists
    accuracies.append(accuracy)
    iterations.append(i)

# After the loop, plot the accuracies
plt.figure(figsize=(10, 6))
plt.plot(iterations, accuracies, marker='o', linestyle='-', color='b')
plt.title('Model Accuracy over Generations')
plt.xlabel('Generation')
plt.ylabel('Accuracy')
plt.xticks(iterations)
plt.ylim(0, 1)
plt.grid(True)
plt.show()
# Out:
# Iteration 1: Accuracy = 0.5305
# Confusion Matrix:
# [[   0    0    9    7    0    0    0]
#  [   0    0   64   48    0    0    0]
#  [   0    0  708  345    2    0    0]
#  [   0    0  417 1002    6    0    0]
#  [   0    0   35  502   13    0    0]
#  [   0    0    1   84    3    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 2: Accuracy = 0.5243
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   63   49    0    0    0]
#  [   0    0  662  393    0    0    0]
#  [   0    0  384 1041    0    0    0]
#  [   0    0   27  523    0    0    0]
#  [   0    0    1   87    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 3: Accuracy = 0.5299
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   64   48    0    0    0]
#  [   0    0  660  395    0    0    0]
#  [   0    0  364 1061    0    0    0]
#  [   0    0   31  519    0    0    0]
#  [   0    0    1   87    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 4: Accuracy = 0.5329
# Confusion Matrix:
# [[   0    0    7    9    0    0    0]
#  [   0    0   61   51    0    0    0]
#  [   0    0  612  443    0    0    0]
#  [   0    0  306 1119    0    0    0]
#  [   0    0   25  525    0    0    0]
#  [   0    0    1   87    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 5: Accuracy = 0.5296
# Confusion Matrix:
# [[   0    0    7    9    0    0    0]
#  [   0    0   65   47    0    0    0]
#  [   0    0  661  394    0    0    0]
#  [   0    0  366 1059    0    0    0]
#  [   0    0   31  519    0    0    0]
#  [   0    0    1   87    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 6: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    7    9    0    0    0]
#  [   0    0   66   46    0    0    0]
#  [   0    0  675  380    0    0    0]
#  [   0    0  382 1043    0    0    0]
#  [   0    0   35  515    0    0    0]
#  [   0    0    1   87    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 7: Accuracy = 0.5277
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   67   45    0    0    0]
#  [   0    0  686  369    0    0    0]
#  [   0    0  397 1028    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    3   85    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 8: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   67   45    0    0    0]
#  [   0    0  694  361    0    0    0]
#  [   0    0  401 1024    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    3   85    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 9: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   67   45    0    0    0]
#  [   0    0  694  361    0    0    0]
#  [   0    0  401 1024    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    3   85    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 10: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   67   45    0    0    0]
#  [   0    0  694  361    0    0    0]
#  [   0    0  401 1024    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    3   85    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 11: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   67   45    0    0    0]
#  [   0    0  694  361    0    0    0]
#  [   0    0  401 1024    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    3   85    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 12: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   67   45    0    0    0]
#  [   0    0  694  361    0    0    0]
#  [   0    0  401 1024    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    3   85    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 13: Accuracy = 0.5286
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   67   45    0    0    0]
#  [   0    0  693  362    0    0    0]
#  [   0    0  401 1024    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    3   85    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 14: Accuracy = 0.5286
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   67   45    0    0    0]
#  [   0    0  693  362    0    0    0]
#  [   0    0  401 1024    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    3   85    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 15: Accuracy = 0.5296
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   63   49    0    0    0]
#  [   0    0  678  377    0    0    0]
#  [   0    0  383 1042    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    2   86    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 16: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   61   51    0    0    0]
#  [   0    0  660  395    0    0    0]
#  [   0    0  367 1058    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    2   86    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 17: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   61   51    0    0    0]
#  [   0    0  660  395    0    0    0]
#  [   0    0  367 1058    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    2   86    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 18: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   61   51    0    0    0]
#  [   0    0  660  395    0    0    0]
#  [   0    0  367 1058    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    2   86    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 19: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   61   51    0    0    0]
#  [   0    0  660  395    0    0    0]
#  [   0    0  367 1058    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    2   86    0    0    0]
#  [   0    0    0    2    0    0    0]]
#
# Iteration 20: Accuracy = 0.5289
# Confusion Matrix:
# [[   0    0    8    8    0    0    0]
#  [   0    0   61   51    0    0    0]
#  [   0    0  660  395    0    0    0]
#  [   0    0  367 1058    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    2   86    0    0    0]
#  [   0    0    0    2    0    0    0]]

# %% [markdown]
# Run the generations

# %%
# Display the confusion matrix
y_pred = rf_model.fit(Xa1_train, ya1_train).predict(Xa1_test)
cm = confusion_matrix(y_true = ya1_test, y_pred = y_pred)
print(cm)
# Out:
# [[   0    0    7    9    0    0    0]
#  [   0   10   62   40    0    0    0]
#  [   0    3  745  295   11    1    0]
#  [   0    1  287 1061   74    2    0]
#  [   0    0   18  295  228    9    0]
#  [   0    0    1   41   20   26    0]
#  [   0    0    0    1    1    0    0]]

# %%
# Plot the Predicted Label vs. True Label accuracy matrix
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
ax.matshow(cmn, cmap=plt.cm.Greys, alpha=0.7)

for i in range(cmn.shape[0]):
    for j in range(cmn.shape[1]):
        ax.text(x=j, y=i, s=f'{cmn[i,j]:.4f}', va='center', ha='center') 

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
y_pred = rf_model.fit(X_synthetic, y_synthetic).predict(Xa1_test)
cm = confusion_matrix(y_true = ya1_test, y_pred = y_pred)
print(cm)

# Plot the Predicted Label vs. True Label accuracy matrix
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig,ax = plt.subplots(figsize=(6,6))
ax.matshow(cmn, cmap=plt.cm.Greys, alpha=0.7)
for i in range(cmn.shape[0]):
    for j in range(cmn.shape[1]):
        ax.text(x=j, y=i, s=f'{cmn[i,j]:.4f}', va='center', ha='center')  
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# [[   0    0    8    8    0    0    0]
#  [   0    0   61   51    0    0    0]
#  [   0    0  660  395    0    0    0]
#  [   0    0  367 1058    0    0    0]
#  [   0    0   40  510    0    0    0]
#  [   0    0    2   86    0    0    0]
#  [   0    0    0    2    0    0    0]]

# %% [markdown]
# Using 'color' as the target variable instead

# %%
# create datasets with and without 'color', with 'quality' added back
wine_data_init = wine_data_init.drop('free_sulfur_dioxide', axis=1)
Xb1 = wine_data_init.drop('color', axis=1)
yb1 = wine_data_init['color']

# %%
# train/test split on the data
# doing 50% split because of equal data in repeated generations
Xb1_train, Xb1_test, yb1_train, yb1_test = train_test_split(Xb1, yb1, test_size=0.5, random_state=123)
# normalize the sizes of the dataframes
Xb1_test = Xb1_test.tail(-1)
yb1_test = yb1_test.tail(-1)

#confirm the data
print(Xb1_test)
print(yb1_test)
print(Xb1_train)
print(yb1_train)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 2767            7.2              0.20         0.38            1.00      0.037
# 5069            6.7              0.24         0.30            3.85      0.042
# 5780            6.6              0.25         0.32            5.60      0.039
# 547            10.6              0.31         0.49            2.50      0.067
# 1769            7.1              0.30         0.46            1.50      0.066
# ...             ...               ...          ...             ...        ...
# 2332            6.6              0.25         0.30           14.40      0.052
# 1920            6.6              0.24         0.35            7.70      0.031
# 3125           14.2              0.27         0.49            1.10      0.037
# 44              6.8              0.67         0.02            1.80      0.050
# 789             8.6              0.63         0.17            2.90      0.099
#
#       total_sulfur_dioxide  density    pH  sulphates  alcohol  quality
# 2767                  74.0  0.99180  3.21       0.37     11.0        5
# 5069                 179.0  0.99189  3.04       0.59     11.3        8
# 5780                  68.0  0.99163  2.96       0.52     11.1        6
# 547                   21.0  0.99870  3.26       0.86     10.7        6
# 1769                 133.0  0.99060  3.12       0.54     12.7        6
# ...                    ...      ...   ...        ...      ...      ...
# 2332                 183.0  0.99800  3.02       0.50      9.1        6
# 1920                 135.0  0.99380  3.19       0.37     10.5        5
# 3125                 156.0  0.99200  3.15       0.54     11.1        6
# 44                    11.0  0.99620  3.48       0.52      9.5        5
# 789                  119.0  0.99800  3.09       0.52      9.3        5
#
# [3248 rows x 11 columns]
# 2767    1
# 5069    1
# 5780    1
# 547     0
# 1769    1
#        ..
# 2332    1
# 1920    1
# 3125    1
# 44      0
# 789     0
# Name: color, Length: 3248, dtype: int64
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 2653            7.0             0.310         0.52            1.70      0.029
# 1376            8.2             0.885         0.20            1.40      0.086
# 2693            7.4             0.240         0.31            8.40      0.045
# 6269            6.6             0.285         0.49           11.40      0.035
# 3319            7.6             0.200         0.39            2.60      0.044
# ...             ...               ...          ...             ...        ...
# 5218            6.8             0.450         0.28           26.05      0.031
# 4060            8.2             0.260         0.33            2.60      0.053
# 1346            6.1             0.590         0.01            2.10      0.056
# 3454            8.0             0.220         0.28           14.00      0.053
# 3582            7.6             0.200         0.30           14.20      0.056
#
#       total_sulfur_dioxide  density    pH  sulphates  alcohol  quality
# 2653                  61.0  0.99180  3.07       0.43     10.4        5
# 1376                  31.0  0.99460  3.11       0.46     10.0        5
# 2693                 183.0  0.99630  3.09       0.32      8.8        5
# 6269                 137.0  0.99732  3.08       0.54      8.9        6
# 3319                 180.0  0.99410  3.46       0.44     10.8        7
# ...                    ...      ...   ...        ...      ...      ...
# 5218                 122.0  1.00295  3.06       0.42     10.6        6
# 4060                  71.0  0.99402  2.89       0.49      9.5        5
# 1346                  13.0  0.99472  3.52       0.56     11.4        5
# 3454                 197.0  0.99810  3.14       0.45      9.8        6
# 3582                 212.5  0.99900  3.14       0.46      8.9        8
#
# [3248 rows x 11 columns]
# 2653    1
# 1376    0
# 2693    1
# 6269    1
# 3319    1
#        ..
# 5218    1
# 4060    1
# 1346    0
# 3454    1
# 3582    1
# Name: color, Length: 3248, dtype: int64

# %%
# initialize rf model (sklearn)
rf_model = RandomForestClassifier(n_estimators=100)
# fit the model on the train data
rf_model.fit(Xb1_train, yb1_train)
# Print the model score based upon the random forest classifier
acc1 = rf_model.score(Xb1_test,yb1_test)
print(acc1)
# Out:
# 0.9941502463054187

# %%
# Display the confusion matrix
y_pred = rf_model.fit(Xb1_train, yb1_train).predict(Xb1_test)
cm = confusion_matrix(y_true = yb1_test, y_pred = y_pred)
print(cm)
# Out:
# [[ 790   15]
#  [   4 2439]]

# %%
# Plot the Predicted Label vs. True Label accuracy matrix
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig,ax = plt.subplots(figsize=(5,5))
ax.matshow(cmn, cmap=plt.cm.Greys, alpha=0.7)
for i in range(cmn.shape[0]):
    for j in range(cmn.shape[1]):
        ax.text(x=j, y=i, s=cmn[i,j], va='center', ha='center')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
accuracies = []
accuracies.append(acc1)
iterations = []
iterations.append(0)

X_synthetic = generate_synthetic_features(rf_model, 3248, Xb1_train)

for i in range(1, 21):
    # Step 1: Generate new synthetic features based on current training set
    X_synthetic = generate_synthetic_features(rf_model, 3248, X_synthetic)
    
    # Step 2: Use the current model to predict labels for the synthetic data
    y_synthetic = rf_model.predict(X_synthetic)
    
    # Step 4: Train a new Random Forest model on the synthetic dataset
    rf_model = RandomForestClassifier(n_estimators=100)
    rf_model.fit(X_synthetic, y_synthetic)
    
    # Step 5: Evaluate the new model on the original fixed test set
    y_test_pred = rf_model.predict(Xb1_test)
    accuracy = accuracy_score(yb1_test, y_test_pred)
    
    # Print the iteration and accuracy
    print(f"Iteration {i}: Accuracy = {accuracy:.4f}")
    cm = confusion_matrix(y_true=yb1_test, y_pred=y_test_pred)
    print(f"Confusion Matrix:\n{cm}\n")
    
    # Append the accuracy and iteration number to the lists
    accuracies.append(accuracy)
    iterations.append(i)

# After the loop, plot the accuracies
plt.figure(figsize=(10, 6))
plt.plot(iterations, accuracies, marker='o', linestyle='-', color='b')
plt.title('Model Accuracy over Generations')
plt.xlabel('Generation')
plt.ylabel('Accuracy')
plt.xticks(iterations)
plt.ylim(0, 1)
plt.grid(True)
plt.show()
# Out:
# Iteration 1: Accuracy = 0.9763
# Confusion Matrix:
# [[ 729   76]
#  [   1 2442]]
#
# Iteration 2: Accuracy = 0.9618
# Confusion Matrix:
# [[ 689  116]
#  [   8 2435]]
#
# Iteration 3: Accuracy = 0.9541
# Confusion Matrix:
# [[ 671  134]
#  [  15 2428]]
#
# Iteration 4: Accuracy = 0.9357
# Confusion Matrix:
# [[ 613  192]
#  [  17 2426]]
#
# Iteration 5: Accuracy = 0.9258
# Confusion Matrix:
# [[ 583  222]
#  [  19 2424]]
#
# Iteration 6: Accuracy = 0.9181
# Confusion Matrix:
# [[ 558  247]
#  [  19 2424]]
#
# Iteration 7: Accuracy = 0.8956
# Confusion Matrix:
# [[ 485  320]
#  [  19 2424]]
#
# Iteration 8: Accuracy = 0.8932
# Confusion Matrix:
# [[ 476  329]
#  [  18 2425]]
#
# Iteration 9: Accuracy = 0.8950
# Confusion Matrix:
# [[ 482  323]
#  [  18 2425]]
#
# Iteration 10: Accuracy = 0.8898
# Confusion Matrix:
# [[ 465  340]
#  [  18 2425]]
#
# Iteration 11: Accuracy = 0.8855
# Confusion Matrix:
# [[ 451  354]
#  [  18 2425]]
#
# Iteration 12: Accuracy = 0.8805
# Confusion Matrix:
# [[ 434  371]
#  [  17 2426]]
#
# Iteration 13: Accuracy = 0.8815
# Confusion Matrix:
# [[ 438  367]
#  [  18 2425]]
#
# Iteration 14: Accuracy = 0.8775
# Confusion Matrix:
# [[ 425  380]
#  [  18 2425]]
#
# Iteration 15: Accuracy = 0.8793
# Confusion Matrix:
# [[ 431  374]
#  [  18 2425]]
#
# Iteration 16: Accuracy = 0.8630
# Confusion Matrix:
# [[ 378  427]
#  [  18 2425]]
#
# Iteration 17: Accuracy = 0.8695
# Confusion Matrix:
# [[ 399  406]
#  [  18 2425]]
#
# Iteration 18: Accuracy = 0.8768
# Confusion Matrix:
# [[ 423  382]
#  [  18 2425]]
#
# Iteration 19: Accuracy = 0.8624
# Confusion Matrix:
# [[ 376  429]
#  [  18 2425]]
#
# Iteration 20: Accuracy = 0.8525
# Confusion Matrix:
# [[ 344  461]
#  [  18 2425]]

# %%
y_pred = rf_model.fit(X_synthetic, y_synthetic).predict(Xb1_test)
cm = confusion_matrix(y_true = yb1_test, y_pred = y_pred)
print(cm)

# Plot the Predicted Label vs. True Label accuracy matrix
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig,ax = plt.subplots(figsize=(5,5))
ax.matshow(cmn, cmap=plt.cm.Greys, alpha=0.7)
for i in range(cmn.shape[0]):
    for j in range(cmn.shape[1]):
        ax.text(x=j, y=i, s=cmn[i,j], va='center', ha='center')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# [[ 349  456]
#  [  18 2425]]
